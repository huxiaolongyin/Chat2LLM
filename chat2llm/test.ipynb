# %%
from pydub import AudioSegment
AudioSegment.from_mp3("test.mp3")
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
import asyncio
from text2speech import Text2Speech

asyncio.run(Text2Speech.tts_stream('你好'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import asyncio
# ----> 2 from chat2llm.api.text2speech import Text2Speech
#       4 asyncio.run(Text2Speech.tts_stream('你好'))
#
# ModuleNotFoundError: No module named 'chat2llm'
